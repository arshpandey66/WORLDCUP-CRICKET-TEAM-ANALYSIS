# %%
import pandas as pd
y=pd.read_html("https://www.espncricinfo.com/records/tournament/team-match-results/icc-men-s-t20-world-cup-2022-23-14450")
z=pd.DataFrame(y[0])
k={}
for i,j in z.iterrows():
    k[j['Team 1']+"vs"+j['Team 2']]=
# Out:
#   Cell In[253], line 6
#     k[j['Team 1']+"vs"+j['Team 2']]=
#                                     ^
# SyntaxError: invalid syntax

# %%
y=pd.read_html("https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-pakistan-final-1298179/full-scorecard")
y=pd.DataFrame(y[0])
y.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19508\1082973026.py in ?()
#       1 y=pd.read_html("https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-pakistan-final-1298179/full-scorecard")
#       2 y=pd.DataFrame(y[0])
# ----> 3 y.drop()
#       4
#
# c:\Users\HP\python\Lib\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5577                 weight  250.0   150.0
#    5578         falcon  speed   320.0   250.0
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#    5584             index=index,
#
# c:\Users\HP\python\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
import json
y=pd.read_json("t20_wc_batting_summary.json")
l=[]
for i in range(len(y)):
    z=y.iloc[i][0]
    for j in range(len(z)):
        l.append(z[j])
l   
m=pd.DataFrame(l)
k=[]
for i in range(len(m)):
    if m['dismissal'][i]=="":
        k.append('not_out')
    else:
        k.append('out')
m['out/not_out']=k
m
m.drop(columns="dismissal",inplace=True)
m
m['batsmanName']=m['batsmanName'].apply(lambda x:x.replace('†',""))
m.head(15)
m['batsmanName']=m['batsmanName'].apply(str)
k=list(m['batsmanName'])
m['batsmanName']=k
m['batsmanName']=m['batsmanName'].astype('string')
for _,b in m.iterrows():
    print(b['batsmanName'])
# Out:
# Michael van Lingen
# Divan la Cock
# Jan Nicol Loftie-Eaton
# Stephan Baard
# Gerhard Erasmus(c)
# Jan Frylinck
# David Wiese
# JJ Smit
# Pathum Nissanka
# Kusal Mendis
# Dhananjaya de Silva
# Danushka Gunathilaka
# Bhanuka Rajapaksa
# Dasun Shanaka(c)
# Wanindu Hasaranga de Silva
# Chamika Karunaratne
# Pramod Madushan
# Dushmantha Chameera
# Maheesh Theekshana
# Chirag Suri
# Muhammad Waseem
# Kashif Daud
# Vriitya Aravind
# Zawar Farid
# Basil Hameed
# Chundangapoyil Rizwan(c)
# Aayan Afzal Khan
# Karthik Meiyappan
# Junaid Siddique
# Vikramjit Singh
# Max O'Dowd
# Bas de Leede
# Colin Ackermann
# Tom Cooper
# Scott Edwards(c)
# Roelof van der Merwe
# Tim Pringle
# Logan van Beek
# George Munsey
# Michael Jones
# Matthew Cross
# Richie Berrington(c)
# Calum MacLeod
# Michael Leask
# Chris Greaves
# Kyle Mayers
# Evin Lewis
# Brandon King
# Nicholas Pooran(c)
# Shamarh Brooks
# Rovman Powell
# Jason Holder
# Akeal Hosein
# Alzarri Joseph
# Odean Smith
# Obed McCoy
# Regis Chakabva
# ...

# %%
import pandas as pd
y=pd.read_html("https://www.espncricinfo.com/records/tournament/team-match-results/icc-men-s-t20-world-cup-2022-23-14450")
z=pd.DataFrame(y[0])
k={}
for i,j in z.iterrows():
    k[j['Team 1']+ " Vs "+j['Team 2']]=j["Scorecard"]
    k[j['Team 2']+ " Vs "+j['Team 1']]=j['Scorecard']
k
# Out:
# {'England Vs Pakistan': 'T20I # 1879',
#  'Pakistan Vs England': 'T20I # 1879',
#  'England Vs India': 'T20I # 1878',
#  'India Vs England': 'T20I # 1878',
#  'New Zealand Vs Pakistan': 'T20I # 1877',
#  'Pakistan Vs New Zealand': 'T20I # 1877',
#  'India Vs Zimbabwe': 'T20I # 1873',
#  'Zimbabwe Vs India': 'T20I # 1873',
#  'Bangladesh Vs Pakistan': 'T20I # 1872',
#  'Pakistan Vs Bangladesh': 'T20I # 1872',
#  'Netherlands Vs South Africa': 'T20I # 1871',
#  'South Africa Vs Netherlands': 'T20I # 1871',
#  'England Vs Sri Lanka': 'T20I # 1867',
#  'Sri Lanka Vs England': 'T20I # 1867',
#  'Australia Vs Afghanistan': 'T20I # 1864',
#  'Afghanistan Vs Australia': 'T20I # 1864',
#  'Ireland Vs New Zealand': 'T20I # 1862',
#  'New Zealand Vs Ireland': 'T20I # 1862',
#  'Pakistan Vs South Africa': 'T20I # 1861',
#  'South Africa Vs Pakistan': 'T20I # 1861',
#  'Bangladesh Vs India': 'T20I # 1860',
#  'India Vs Bangladesh': 'T20I # 1860',
#  'Netherlands Vs Zimbabwe': 'T20I # 1859',
# ...

# %%
m['match_id']=m['match'].apply(lambda x:k[x])
m
# Out:
#                     match bowlingTeam                  bowlerName overs  \
# 0    Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4
# 1    Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4
# 2    Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4
# 3    Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4
# 4    Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4
# ..                    ...         ...                         ...   ...
# 495   Pakistan Vs England    Pakistan                 Naseem Shah     4
# 496   Pakistan Vs England    Pakistan                  Haris Rauf     4
# 497   Pakistan Vs England    Pakistan                 Shadab Khan     4
# 498   Pakistan Vs England    Pakistan              Mohammad Wasim     4
# 499   Pakistan Vs England    Pakistan              Iftikhar Ahmed   0.5
#
#     maiden runs wickets economy  0s 4s 6s wides noBalls     match_id
# ...

# %% [markdown]
# bowling summary

# %%
a=pd.read_json('t20_wc_bowling_summary.json')
l=[]
for i in range(len(a)):
    for j in range(len(a.loc[i][0])):
        l.append((a.loc[i][0][j]))
m=pd.DataFrame(l)
m['match_id']=m['match'].apply(lambda x:k[x])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19508\396352270.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   for j in range(len(a.loc[i][0])):
# C:\Users\HP\AppData\Local\Temp\ipykernel_19508\396352270.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l.append((a.loc[i][0][j]))

# %%
y=pd.read_json('t20_wc_match_results.json')
L=[]
for i in range(len(y.loc[0][0])):
    L.append(y.loc[0][0][i])
pd.DataFrame(L).to_csv("MATCHRESULT.CSV")
y=pd.DataFrame(L)
y
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19508\3920938866.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   for i in range(len(y.loc[0][0])):
# C:\Users\HP\AppData\Local\Temp\ipykernel_19508\3920938866.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   L.append(y.loc[0][0][i])
#            team1         team2        winner      margin     ground  \
# 0        Namibia     Sri Lanka       Namibia     55 runs    Geelong
# 1    Netherlands        U.A.E.   Netherlands   3 wickets    Geelong
# 2       Scotland   West Indies      Scotland     42 runs     Hobart
# ...

# %%
y=pd.read_json("t20_wc_batting_summary.json")
l=[]
for i in range(len(y)):
    for j in range(len(y.loc[i][0])):
        l.append(y.loc[i][0][j])
m=pd.DataFrame(l)
m.to_csv('battingsummary.csv')
m['match_id']=m['match_id']=m['match'].apply(lambda x:k[x])
m.to_csv('batting.csv')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19508\58465825.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   for j in range(len(y.loc[i][0])):
# C:\Users\HP\AppData\Local\Temp\ipykernel_19508\58465825.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   l.append(y.loc[i][0][j])
